# %%
from langchain_mcp_adapters.client import MultiServerMCPClient
import json

# %%
mcp_client = MultiServerMCPClient(
        json.load(open("new_tools.json"))
    )

li=["math","research"]
tools = [mcp_client.get_tools(server_name=name) for name in li]

# %%
tools
# Out:
# [<coroutine object MultiServerMCPClient.get_tools at 0x000002AAA86A8970>,
#  <coroutine object MultiServerMCPClient.get_tools at 0x000002AAA86A8820>]

# %%
    tools = mcp_client.get_tools()

# %%
tools
# Out:
# <coroutine object MultiServerMCPClient.get_tools at 0x000002AAA6AA3CA0>
