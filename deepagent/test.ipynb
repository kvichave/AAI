# %%
import os
import json
from deepagents import create_deep_agent
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain.tools import tool

# %%
from langchain_openai import ChatOpenAI

# %%
PROJECT_ID = "sbx-31371-79b51c7781a2"
LOCATION_ID = "europe-west1"
# Use the exact model ID that worked in your Postman URL
MODEL_ID = "claude-opus-4-6"

# %%
llm = ChatOpenAI(
    model="DeepSeek-V3.2",
    base_url="https://agent-factory.openai.azure.com/openai/v1/",
    api_key=os.getenv("AZURE_MODEL"),
    temperature=0,
)

# %%
os.environ["AZURE_OPENAI_ENDPOINT"] = os.getenv("AZURE_AI_PROJECT_ENDPOINT")
os.environ["OPENAI_API_VERSION"] = "2024-05-01-preview"

agent = create_deep_agent(model=llm)

# %%
from langchain_core.messages import HumanMessage

# %%
agent.invoke(
                {"messages": [HumanMessage(content="hello")]}
               
            )
# Out:
# {'messages': [HumanMessage(content='hello', additional_kwargs={}, response_metadata={}, id='0d8e2e22-92db-4287-bb29-0cd1c9ea7514'),
#   AIMessage(content='Hello! How can I help you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 5959, 'total_tokens': 5969, 'completion_tokens_details': None, 'prompt_tokens_details': None, 'audio_prompt_tokens': 0, 'reasoning_tokens': 0}, 'model_provider': 'openai', 'model_name': 'deepseek-v3.2', 'system_fingerprint': None, 'id': '6bbc4650e77b420b867d035f12020694', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d4cce-22f7-7981-aebb-be42c0de1c22-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 5959, 'output_tokens': 10, 'total_tokens': 5969, 'input_token_details': {}, 'output_token_details': {}})]}
